# %%
import pandas as pd
import seaborn as sns

# %%
column_names = ['area', 'perimeter', 'compactness', 'kernel_length', 'kernel_width', 'asymmetry_coefficient', 'kernel_groove_length', 'type']
seeds = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00236/seeds_dataset.txt', sep='\s+', names=column_names)
seeds.head()
# Out:
#     area  perimeter  compactness  kernel_length  kernel_width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    asymmetry_coefficient  kernel_groove_length  type
# 0                  2.221                 5.220     1
# 1                  1.018                 4.956     1
# 2                  2.699                 4.825     1
# 3                  2.259                 4.805     1
# 4                  1.355                 5.175     1

# %%
seeds.shape
# Out:
# (210, 7)

# %%
seeds.corr()
# Out:
#                            area  perimeter  compactness  kernel_length  \
# area                   1.000000   0.994341     0.608288       0.949985
# perimeter              0.994341   1.000000     0.529244       0.972422
# compactness            0.608288   0.529244     1.000000       0.367915
# kernel_length          0.949985   0.972422     0.367915       1.000000
# kernel_width           0.970771   0.944829     0.761635       0.860415
# asymmetry_coefficient -0.229572  -0.217340    -0.331471      -0.171562
# kernel_groove_length   0.863693   0.890784     0.226825       0.932806
# type                  -0.346058  -0.327900    -0.531007      -0.257269
#
#                        kernel_width  asymmetry_coefficient  \
# area                       0.970771              -0.229572
# perimeter                  0.944829              -0.217340
# compactness                0.761635              -0.331471
# kernel_length              0.860415              -0.171562
# kernel_width               1.000000              -0.258037
# asymmetry_coefficient     -0.258037               1.000000
# kernel_groove_length       0.749131              -0.011079
# type                      -0.423463               0.577273
#
#                        kernel_groove_length      type
# area                               0.863693 -0.346058
# perimeter                          0.890784 -0.327900
# compactness                        0.226825 -0.531007
# kernel_length                      0.932806 -0.257269
# kernel_width                       0.749131 -0.423463
# asymmetry_coefficient             -0.011079  0.577273
# kernel_groove_length               1.000000  0.024301
# type                               0.024301  1.000000

# %%
sns.pairplot(seeds, hue='type')
